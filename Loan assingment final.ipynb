# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_raw = pd.read_csv('train.csv')
# i have sucessfuly imported data in pandas data frame
df_raw
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_raw.head(10)
# view of top ten rows of data frame
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df_raw.describe(include='all')
# by discribe i am able to see catagorical data and unique enteries and number of count
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP002622   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
df_raw.isnull().sum()
# here i have find total of null cells in data frame
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_raw.info()
#here i have found objet type data in following columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df_raw.drop(['Loan_ID'], axis=1, inplace=True) # here i have drop loan id column

# %%
pd.set_option('display.max_rows', None) # here i have set pandas to display all rows 
df_raw['Dependents'].value_counts()
# here seems that 51 enteries are 3+ and from little google i have found that average size of a indian family is 4
# so i am replacing all 3+ enteries to 4
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
sns.countplot(df_raw['Dependents'])
plt.show()

# %%
df_raw.replace(to_replace='3+', value=4, inplace=True)

# %%
df_raw['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
sns.countplot(df_raw['Education'])
plt.show()

# %%
df_raw['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
sns.countplot(df_raw['Self_Employed'])
plt.show()

# %%
df_raw['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
sns.countplot(df_raw['Married'])
plt.show()

# %%
df_raw['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
sns.countplot(df_raw['Gender'])
plt.show()

# %%
df_raw['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
sns.countplot(df_raw['Self_Employed'])
plt.show()

# %%
df_raw['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
sns.countplot(df_raw['Property_Area'])
plt.show()

# %%
df_raw.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# i am simply droping all row with null values as it is less than 5% of given data
df_raw = df_raw.dropna()
df = df_raw.reset_index(drop=True)

# %%
df.describe(include='all')
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     480     480        480       480           480       480.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      394     311        274       383           414              NaN
# mean      NaN     NaN        NaN       NaN           NaN      5364.231250
# std       NaN     NaN        NaN       NaN           NaN      5668.251251
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2898.750000
# 50%       NaN     NaN        NaN       NaN           NaN      3859.000000
# 75%       NaN     NaN        NaN       NaN           NaN      5852.500000
# max       NaN     NaN        NaN       NaN           NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
sns.distplot(df['ApplicantIncome'])

# here seems to be some outliers

# %%
q = df['ApplicantIncome'].quantile(0.99)
df1 = df[df['ApplicantIncome']<q]

# %%
sns.distplot(df1['ApplicantIncome'])

# %%
df1.drop(['CoapplicantIncome'], axis=1, inplace=True)
df1.describe(include='all')
# Out:
# /home/ni/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     475     475        475       475           475       475.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      389     307        273       378           410              NaN
# mean      NaN     NaN        NaN       NaN           NaN      4932.884211
# std       NaN     NaN        NaN       NaN           NaN      3369.568634
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# ...

# %%
df_raw['Loan_Amount_Term']
# Out:
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
# 5      360.0
# 6      360.0
# 7      360.0
# 8      360.0
# 9      360.0
# 10     360.0
# 12     360.0
# 13     360.0
# 14     120.0
# 15     360.0
# 17     360.0
# 18     360.0
# 20     360.0
# 21     360.0
# 22     360.0
# 25     360.0
# 26     360.0
# 27     360.0
# 28     360.0
# 31     360.0
# 32     360.0
# 33     360.0
# 34     360.0
# 37     360.0
# 38     360.0
# 39     360.0
# 40     360.0
# 41     360.0
# 43     360.0
# 46     360.0
# 47     360.0
# 48     360.0
# 49     360.0
# 50     360.0
# 51     360.0
# 52     360.0
# 53     360.0
# 54     360.0
# 55     360.0
# 56     360.0
# 57     360.0
# 58     360.0
# 59     360.0
# 60     360.0
# 61     360.0
# 62     180.0
# 64     360.0
# 65     360.0
# 66     180.0
# 67     360.0
# 68      60.0
# 69     360.0
# 70     360.0
# 71     360.0
# 72     300.0
# 74     360.0
# 75     480.0
# 76     360.0
# 77     360.0
# 78     300.0
# 80     360.0
# 82     360.0
# ...

# %%
df1.describe(include='all')
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     475     475        475       475           475       475.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      389     307        273       378           410              NaN
# mean      NaN     NaN        NaN       NaN           NaN      4932.884211
# std       NaN     NaN        NaN       NaN           NaN      3369.568634
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2892.000000
# 50%       NaN     NaN        NaN       NaN           NaN      3850.000000
# 75%       NaN     NaN        NaN       NaN           NaN      5816.500000
# max       NaN     NaN        NaN       NaN           NaN     20233.000000
#
#         LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# ...

# %%
x=df1.iloc[:,:11]
y=df1.iloc[:,-1]

# %%
x_dummies = pd.get_dummies(x, drop_first=True)
# here i have used get dummies method to covert catagorical data, i am not using one hot encoder as needs time to understand :)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_dummies)
x_scaled = scaler.transform(x_dummies)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2)

# %%
# i have used descision tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
dt.score(x_test,y_test) # my model is over fitting and test also have 100% acquracy which tells some thing is wrong
# Out:
# 1.0

# %%
# i am checking whether it same for other classifiers also or not
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression()
lg.fit(x_train,y_train)
# Out:
# /home/ni/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lg.score(x_test,y_test) # same propblem
# Out:
# 1.0

# %%
# with another one
from sklearn.svm import SVC
svc = SVC(kernel = 'linear', random_state = 0)
svc.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=0,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc.score(x_test,y_test)
# Out:
# 1.0

# %%
# by the way i am using ensemble learning although my previous classifiers are overfitting
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=20)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
from sklearn.ensemble import BaggingClassifier
bc = BaggingClassifier(DecisionTreeClassifier(), max_samples= 0.5, max_features = 1.0, n_estimators = 20)
bc.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort=False,
#                                                         random_state=None,
# ...

# %%
# boosting ensemble 
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier(DecisionTreeClassifier(),n_estimators = 5, learning_rate = 1)
adb.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=None,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort=False,
#                                                          random_state=None,
# ...

# %%
# here i am making my own ensemble by using votting
from sklearn.ensemble import VotingClassifier
evc = VotingClassifier( estimators= [('lg',lg),('svc',svc)], voting = 'hard')
evc.fit(x_train,y_train)
evc.score(x_test, y_test)
# i have used two classification method logistic and vector machin to make my ensamble
# Out:
# /home/ni/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 1.0
